# %%
import pandas as pd

# %%
#Reading the excel file

xls = pd.ExcelFile('PHIDU Social Health Atlas by LGA Various Dates.xls')

# %%
# Displaying the sheets from the excel file

xls.sheet_names
# Out:
# ['Front_page',
#  'Contents',
#  'Age_distribution_Males',
#  'Age_distribution_Females',
#  'Age_distribution_Persons',
#  'Age_distribution_Males_broad',
#  'Age_distribution_Females_broad',
#  'Age_distribution_Persons_broad',
#  'Aboriginal_males',
#  'Aboriginal_females',
#  'Aboriginal_persons',
#  'Indigenous_status',
#  'Indigenous_status_age',
#  'Birthplace_NES_residents',
#  'Birthplace_Top_ten_NES',
#  'Migrants_humanitarian',
#  'Migrants_family',
#  'Migrants_skilled',
#  'Total_fertility_rate',
#  'Education',
#  'Early_childhood_development',
#  'Learning_Earning',
#  'Families',
#  'Child_care',
#  'Housing_Transport',
#  'Income_support',
#  'Internet_access',
#  'Labour_force',
#  'IRSD',
#  'Community_strength',
#  'Financial_stress',
#  'Access_to_services',
#  'Mothers_babies',
#  'Child_youth_health',
#  'Screening',
#  'Cancer_incidence_males',
#  'Cancer_incidence_females',
#  'Cancer_incidence_persons',
#  'Estimates_self_assessed_health',
# ...

# %%
#Read the data from sheet 'Age_distribution_Females' 

df = xls.parse(sheet_name='Age_distribution_Females')
df
# Out:
#          © 2020 PHIDU  \
# 0    BACK TO CONTENTS
# 1         Link to Key
# 2                 NaN
# 3                Code
# 4     NEW SOUTH WALES
# ..                ...
# 617               NaN
# 618               NaN
# 619               NaN
# 620               NaN
# 621               NaN
#
#     This content is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 3.0 Australia licence.    \
# 0                            Link to Notes on the data
# 1                                                  NaN
# 2       Link to Australian and State/ Territory totals
# 3                                                 Name
# 4                                                  NaN
# ..                                                 ...
# 617  +Includes external territories (where data cod...
# 618                                                NaN
# 619  ++Major Urban Centres include Illawarra, Newca...
# 620                                                NaN
# ...

# %%
# As you can see above there are a lot of NaN values
# Trying to read the data properly 

df = xls.parse(sheet_name='Age_distribution_Females', skiprows=4)

# %%
#Displaying the first few records from the dataframe

df.head()
# Out:
#               Code                   Name Number Total females        %  \
# 0  NEW SOUTH WALES                    NaN    NaN           NaN      NaN
# 1            10050             Albury (C)   1740         27727  6.27547
# 2            10130  Armidale Regional (A)    893         15768  5.66337
# 3            10250            Ballina (A)   1083         22843  4.74106
# 4            10300          Balranald (A)     81          1135  7.13656
#
#    Unnamed: 5 Number.1 Total females.1      %.1  Unnamed: 9  ...  \
# 0         NaN      NaN             NaN      NaN         NaN  ...
# 1         NaN     1709           27727  6.16367         NaN  ...
# 2         NaN      893           15768  5.66337         NaN  ...
# 3         NaN     1263           22843  5.52905         NaN  ...
# 4         NaN       68            1135  5.99119         NaN  ...
#
#   Total females.15     %.15 Unnamed: 65  Number.16 Total females.16     %.16  \
# ...

# %%
#displaying the name of the columns 
df.columns
# Out:
# Index(['Code', 'Name', 'Number', 'Total females', '%', 'Unnamed: 5',
#        'Number.1', 'Total females.1', '%.1', 'Unnamed: 9', 'Number.2',
#        'Total females.2', '%.2', 'Unnamed: 13', 'Number.3', 'Total females.3',
#        '%.3', 'Unnamed: 17', 'Number.4', 'Total females.4', '%.4',
#        'Unnamed: 21', 'Number.5', 'Total females.5', '%.5', 'Unnamed: 25',
#        'Number.6', 'Total females.6', '%.6', 'Unnamed: 29', 'Number.7',
#        'Total females.7', '%.7', 'Unnamed: 33', 'Number.8', 'Total females.8',
#        '%.8', 'Unnamed: 37', 'Number.9', 'Total females.9', '%.9',
#        'Unnamed: 41', 'Number.10', 'Total females.10', '%.10', 'Unnamed: 45',
#        'Number.11', 'Total females.11', '%.11', 'Unnamed: 49', 'Number.12',
#        'Total females.12', '%.12', 'Unnamed: 53', 'Number.13',
#        'Total females.13', '%.13', 'Unnamed: 57', 'Number.14',
#        'Total females.14', '%.14', 'Unnamed: 61', 'Number.15',
# ...

# %%
#Renaming the Columns


df = df.rename(columns={'Number': 'Number_0-4',
                  '%': 'percentage_0-4',
                  'Number.1': 'Number_5-9',
                  '%.1':'percentage_5-9',
                  'Number.2': 'Number_10-14',
                   '%.2': 'percentage_10-14',
                   'Number.3': 'Number_15-19',
                   '%.3': 'percentage_15-19',
                   'Number.4': 'Number_20-24',
                   '%.4': 'percentage_20-24',
                   'Number.5': 'Number_25-29',
                   '%.5': 'percentage_25-29',
                   'Number.6': 'Number_30-34',
                   '%.6': 'percentage_30-34',
                   'Number.7': 'Number_35-39',
                   '%.7': 'percentage_35-39',
                   'Number.8': 'Number_40-44',
                   '%.8': 'percentage_40-44',
                   'Number.9': 'Number_45-49',
                   '%.9': 'percentage_45-49',
                   'Number.10': 'Number_50-54',
                   '%.10': 'percentage_50-54',
                   'Number.11': 'Number_55-59',
                   '%.11': 'percentage_55-59',
                   'Number.12': 'Number_60-64',
                   '%.12': 'percentage_60-64',
                   'Number.13': 'Number_65-69',
                   '%.13': 'percentage_65-69',
                   'Number.14': 'Number_70-74',
                   '%.14': 'percentage_70-74',
                   'Number.15': 'Number_75-79',
                   '%.15': 'percentage_75-79',
                   'Number.16': 'Number_80-84',
                   '%.16': 'percentage_80-84',
                   'Number.17': 'Number_85_over',
                   '%.17': 'percentage_85_over',
                  })

# %%
#Displaying the first few records after changing the column names

df.head()
# Out:
#               Code                   Name Number_0-4 Total females  \
# 0  NEW SOUTH WALES                    NaN        NaN           NaN
# 1            10050             Albury (C)       1740         27727
# 2            10130  Armidale Regional (A)        893         15768
# 3            10250            Ballina (A)       1083         22843
# 4            10300          Balranald (A)         81          1135
#
#   percentage_0-4  Unnamed: 5 Number_5-9 Total females.1 percentage_5-9  \
# 0            NaN         NaN        NaN             NaN            NaN
# 1        6.27547         NaN       1709           27727        6.16367
# 2        5.66337         NaN        893           15768        5.66337
# 3        4.74106         NaN       1263           22843        5.52905
# 4        7.13656         NaN         68            1135        5.99119
#
#    Unnamed: 9  ... Total females.15 percentage_75-79 Unnamed: 65  \
# 0         NaN  ...              NaN              NaN         NaN
# ...

# %%
# Displayimg the name of the columns after re-naming

cols1 = list(df.columns)
cols1 = [x for x in cols1]
cols1
# Out:
# ['Code',
#  'Name',
#  'Number_0-4',
#  'Total females',
#  'percentage_0-4',
#  'Unnamed: 5',
#  'Number_5-9',
#  'Total females.1',
#  'percentage_5-9',
#  'Unnamed: 9',
#  'Number_10-14',
#  'Total females.2',
#  'percentage_10-14',
#  'Unnamed: 13',
#  'Number_15-19',
#  'Total females.3',
#  'percentage_15-19',
#  'Unnamed: 17',
#  'Number_20-24',
#  'Total females.4',
#  'percentage_20-24',
#  'Unnamed: 21',
#  'Number_25-29',
#  'Total females.5',
#  'percentage_25-29',
#  'Unnamed: 25',
#  'Number_30-34',
#  'Total females.6',
#  'percentage_30-34',
#  'Unnamed: 29',
#  'Number_35-39',
#  'Total females.7',
#  'percentage_35-39',
#  'Unnamed: 33',
#  'Number_40-44',
#  'Total females.8',
#  'percentage_40-44',
#  'Unnamed: 37',
#  'Number_45-49',
#  'Total females.9',
#  'percentage_45-49',
#  'Unnamed: 41',
#  'Number_50-54',
#  'Total females.10',
#  'percentage_50-54',
#  'Unnamed: 45',
#  'Number_55-59',
#  'Total females.11',
#  'percentage_55-59',
#  'Unnamed: 49',
# ...

# %%
#Removing the unnecessary columns like (e.g 'Unnamed: 5','Unnamed: 9', etc)

df = df.drop(['Unnamed: 5','Unnamed: 9','Unnamed: 13','Unnamed: 17','Unnamed: 21','Unnamed: 25',
        'Unnamed: 29','Unnamed: 33','Unnamed: 37','Unnamed: 41','Unnamed: 45','Unnamed: 49',
        'Unnamed: 53','Unnamed: 57','Unnamed: 61','Unnamed: 65','Unnamed: 69'], axis=1)

# %%
#Removing the unnecessary columns like (e.g 'Total females.1','Total females.2', etc)


df = df.drop(['Total females.1','Total females.2','Total females.3','Total females.4','Total females.5',
              'Total females.6', 'Total females.7','Total females.8','Total females.9','Total females.10',
              'Total females.11','Total females.12','Total females.13','Total females.14',
              'Total females.15','Total females.16','Total females.17'], axis=1)

# %%
#displaying the first few records.

df.head()
# Out:
#               Code                   Name Number_0-4 Total females  \
# 0  NEW SOUTH WALES                    NaN        NaN           NaN
# 1            10050             Albury (C)       1740         27727
# 2            10130  Armidale Regional (A)        893         15768
# 3            10250            Ballina (A)       1083         22843
# 4            10300          Balranald (A)         81          1135
#
#   percentage_0-4 Number_5-9 percentage_5-9 Number_10-14 percentage_10-14  \
# 0            NaN        NaN            NaN          NaN              NaN
# 1        6.27547       1709        6.16367         1655          5.96891
# 2        5.66337        893        5.66337          917          5.81558
# 3        4.74106       1263        5.52905         1196          5.23574
# 4        7.13656         68        5.99119           80          7.04846
#
#   Number_15-19  ... Number_65-69 percentage_65-69 Number_70-74  \
# ...

# %%
#Checking the datatypes of the columns.

df.dtypes
# Out:
# Code                  object
# Name                  object
# Number_0-4            object
# Total females         object
# percentage_0-4        object
# Number_5-9            object
# percentage_5-9        object
# Number_10-14          object
# percentage_10-14      object
# Number_15-19          object
# percentage_15-19      object
# Number_20-24          object
# percentage_20-24      object
# Number_25-29          object
# percentage_25-29      object
# Number_30-34          object
# percentage_30-34      object
# Number_35-39          object
# percentage_35-39      object
# Number_40-44          object
# percentage_40-44      object
# Number_45-49          object
# percentage_45-49      object
# Number_50-54          object
# percentage_50-54      object
# Number_55-59          object
# percentage_55-59      object
# Number_60-64          object
# percentage_60-64      object
# Number_65-69          object
# percentage_65-69      object
# Number_70-74          object
# ...

# %%
#removing the rows by id in which records are unnecessary

df = df[df.Code != 19999]
df = df[df.Code != 49999]
df = df[df.Code != 44000]
df = df[df.Code != 57630]
df = df[df.Code != 29999]
df = df[df.Code != 39999]
df = df[df.Code != 59999]
df = df[df.Code != 69999]
df = df[df.Code != 79999]

# %%
#Changing the column datatype to string type

df['Code'].astype('str')
# Out:
# 0      NEW SOUTH WALES
# 1                10050
# 2                10130
# 3                10250
# 4                10300
#             ...
# 613                nan
# 614                nan
# 615                nan
# 616                nan
# 617                nan
# Name: Code, Length: 609, dtype: object

# %%
#Calculating the number of females between age 0-4 for all the states



###### NSW
no_of_females = []

for k in df['Code']:
    if str(k).startswith('1'):
        no_of_females.append(df.loc[df['Code'] == k, 'Number_0-4'].iloc[0])
        
no_of_females_0_4_NSW = sum(no_of_females)
print("New South Wales Females(0-4) : ", round(no_of_females_0_4_NSW))



###### Victoria
no_of_females = []

for k in df['Code']:
    if str(k).startswith('2'):
        no_of_females.append(df.loc[df['Code'] == k, 'Number_0-4'].iloc[0])
        
no_of_females_0_4_VIC = sum(no_of_females)
print("Victoria State Females(0-4) : ", round(no_of_females_0_4_VIC))


###### Queensland
no_of_females = []

for k in df['Code']:
    if str(k).startswith('3'):
        no_of_females.append(df.loc[df['Code'] == k, 'Number_0-4'].iloc[0])
        
no_of_females_0_4_Queensland = sum(no_of_females)
print("Queensland Females(0-4) : ",round(no_of_females_0_4_Queensland))


###### South Australia
no_of_females = []

for k in df['Code']:
    if str(k).startswith('4'):
        no_of_females.append(df.loc[df['Code'] == k, 'Number_0-4'].iloc[0])
        
no_of_females_0_4_SA = sum(no_of_females)
print("South Australia Females(0-4) : ", round(no_of_females_0_4_SA))



#### Western Australia

no_of_females = []

for k in df['Code']:
    if str(k).startswith('5'):
        no_of_females.append(df.loc[df['Code'] == k, 'Number_0-4'].iloc[0])
        
no_of_females_0_4_WA = sum(no_of_females)
print("Western Australia Females(0-4) : ",round(no_of_females_0_4_WA))


#### Tasmania

no_of_females = []

for k in df['Code']:
    if str(k).startswith('6'):
        no_of_females.append(df.loc[df['Code'] == k, 'Number_0-4'].iloc[0])
        
no_of_females_0_4_TAS = sum(no_of_females)
print("Tasmania Females(0-4) : ",round(no_of_females_0_4_TAS))


#### Northern Territory
no_of_females = []

for k in df['Code']:
    if str(k).startswith('7'):
        no_of_females.append(df.loc[df['Code'] == k, 'Number_0-4'].iloc[0])
        
no_of_females_0_4_NT = sum(no_of_females)
print("Northern Territory Females(0-4) : ",round(no_of_females_0_4_NT))
# Out:
# New South Wales Females(0-4) :  247039
# Victoria State Females(0-4) :  197568
# Queensland Females(0-4) :  154623
# South Australia Females(0-4) :  48785
# Western Australia Females(0-4) :  84113
# Tasmania Females(0-4) :  14354
# Northern Territory Females(0-4) :  9042

# %%
#Calculating the total number of females in different states.

#Total Number of Females

############ NSW.
Total_no_of_females = []

for k in df['Code']:
    if str(k).startswith('1'):
        Total_no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
Total_no_of_females_2018 = sum(Total_no_of_females) 
print("Total Females in NSW : ", Total_no_of_females_2018)


############ Victoria.
Total_no_of_females = []

for k in df['Code']:
    if str(k).startswith('2'):
        Total_no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
Total_no_of_females_2018 = sum(Total_no_of_females) 
print("Total Number of Females in Victoria : ", Total_no_of_females_2018)

############ Queensland.
Total_no_of_females = []

for k in df['Code']:
    if str(k).startswith('3'):
        Total_no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
Total_no_of_females_2018 = sum(Total_no_of_females) 
print("Total Number of Females in Queensland : ", Total_no_of_females_2018)

############ South Australia.
Total_no_of_females = []

for k in df['Code']:
    if str(k).startswith('4'):
        Total_no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
Total_no_of_females_2018 = sum(Total_no_of_females) 
print("Total Number of Females in South Australia : ", Total_no_of_females_2018)


############### Western Australia.
Total_no_of_females = []

for k in df['Code']:
    if str(k).startswith('5'):
        Total_no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
Total_no_of_females_2018 = sum(Total_no_of_females) 
print("Total Number of Females in Western Australia : ", Total_no_of_females_2018)


############## Tasmania.
Total_no_of_females = []

for k in df['Code']:
    if str(k).startswith('6'):
        Total_no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
Total_no_of_females_2018 = sum(Total_no_of_females) 
print("Total Number of Females in Tasmania : ", Total_no_of_females_2018)



############## Northern Territory.
Total_no_of_females = []

for k in df['Code']:
    if str(k).startswith('7'):
        Total_no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
Total_no_of_females_2018 = sum(Total_no_of_females) 
print("Total Number of Females in Northern Territory : ", Total_no_of_females_2018)
# Out:
# Total Females in NSW :  4024456.0
# Total Number of Females in Victoria :  3263556
# Total Number of Females in Queensland :  2530808.0
# Total Number of Females in South Australia :  878506
# Total Number of Females in Western Australia :  1297436.0
# Total Number of Females in Tasmania :  266767
# Total Number of Females in Northern Territory :  119091

# %%
#Checking the data type of elements in the list

for element in no_of_females:
        if isinstance(element, int):
            print("It's an Integer")
        if isinstance(element, str):
            print("It's an string")
        if isinstance(element, float):
            print("It's an floating number")
# Out:
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer
# It's an Integer

# %%
#calculated the number of females in NSW state between age 0-4 ------------> 6.13%

(no_of_females_0_4_NSW/Total_no_of_females_2018)*100
# Out:
# 207.43716989529014

# %%
############ Displaying the names of Suburbs in Victoria LGA ###################


Total_no_of_females = []
for k in df['Code']:
    if str(k).startswith('1'):
        Total_no_of_females.append((df.loc[df['Code'] == k, 'Total females']))

for i in Total_no_of_females:
    print(i)
# Total_no_of_females.append(df.loc[df['Code'] == k, 'Name'].iloc[0])
# Total_no_of_females_2018 = sum(Total_no_of_females) 
# print("Total Number of Females in Victoria : ", Total_no_of_females_2018)
# Out:
# 1    27727
# Name: Total females, dtype: object
# 2    15768
# Name: Total females, dtype: object
# 3    22843
# Name: Total females, dtype: object
# 4    1135
# Name: Total females, dtype: object
# 5    21497
# Name: Total females, dtype: object
# 6    17488
# Name: Total females, dtype: object
# 7    6658
# Name: Total females, dtype: object
# 8    4341
# Name: Total females, dtype: object
# 9    182947
# Name: Total females, dtype: object
# 10    2971
# Name: Total females, dtype: object
# 11    3666
# Name: Total females, dtype: object
# 12    40661
# Name: Total females, dtype: object
# 13    1301
# Name: Total females, dtype: object
# 14    26403.2
# Name: Total females, dtype: object
# 15    1368
# Name: Total females, dtype: object
# 16    772
# Name: Total females, dtype: object
# 17    9083
# Name: Total females, dtype: object
# 18    20294
# Name: Total females, dtype: object
# 19    17867
# Name: Total females, dtype: object
# 20    6802
# ...

# %%
########## I am doing further analysis will continue on saturday...............Thanks. :)

# %%
df.head()
# Out:
#               Code                   Name Number_0-4 Total females  \
# 0  NEW SOUTH WALES                    NaN        NaN           NaN
# 1            10050             Albury (C)       1740         27727
# 2            10130  Armidale Regional (A)        893         15768
# 3            10250            Ballina (A)       1083         22843
# 4            10300          Balranald (A)         81          1135
#
#   percentage_0-4 Number_5-9 percentage_5-9 Number_10-14 percentage_10-14  \
# 0            NaN        NaN            NaN          NaN              NaN
# 1        6.27547       1709        6.16367         1655          5.96891
# 2        5.66337        893        5.66337          917          5.81558
# 3        4.74106       1263        5.52905         1196          5.23574
# 4        7.13656         68        5.99119           80          7.04846
#
#   Number_15-19  ... Number_65-69 percentage_65-69 Number_70-74  \
# ...

# %% [markdown]
# ### Top 20 LGA's in different states...

# %%
# Top 20 LGA's in NSW.

no_of_females_NSW = []
LGA = []
x_NSW = []

for k in df['Code']:
    if str(k).startswith('1'):
        no_of_females_NSW.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
        
        
no_of_females_NSW.sort(reverse = True)
print(no_of_females_NSW[0:20])


for i in no_of_females_NSW[0:20]:
    x_NSW.append(i)
    print(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    LGA.append(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    #print(df.iloc[df['Total females'] == i, 'Name'].iloc[0])

print(LGA)
print(x_NSW)

#Bar Chart 
x_pos = [i for i, _ in enumerate(LGA)]

plt.bar(LGA, x_NSW)
plt.xlabel("Local Government Area")
plt.ylabel("Number of LGA's")
plt.title("Top 20 LGA's in NSW")
#plt.figure(figsize=(3,4))
plt.xticks(x_pos, LGA, rotation='vertical')
#plt.rcParams['figure.figsize'] = [10, 15]
plt.show()


print(x_NSW)
# Out:
# [186196, 182947, 174907, 137760, 124201, 116377, 115639, 113743, 111927, 108871, 105823, 105019, 104718, 100497, 86872, 84988, 82554, 80000, 77514, 76336]
# Canterbury-Bankstown (A)
# Blacktown (C)
# Central Coast (C) (NSW)
# Northern Beaches (A)
# Parramatta (C)
# Sutherland Shire (A)
# Sydney (C)
# Cumberland (A)
# Liverpool (C)
# Wollongong (C)
# Fairfield (C)
# Penrith (C)
# Lake Macquarie (C)
# Inner West (A)
# The Hills Shire (A)
# Campbelltown (C) (NSW)
# Newcastle (C)
# Georges River (A)
# Randwick (C)
# Hornsby (A)
# ['Canterbury-Bankstown (A)', 'Blacktown (C)', 'Central Coast (C) (NSW)', 'Northern Beaches (A)', 'Parramatta (C)', 'Sutherland Shire (A)', 'Sydney (C)', 'Cumberland (A)', 'Liverpool (C)', 'Wollongong (C)', 'Fairfield (C)', 'Penrith (C)', 'Lake Macquarie (C)', 'Inner West (A)', 'The Hills Shire (A)', 'Campbelltown (C) (NSW)', 'Newcastle (C)', 'Georges River (A)', 'Randwick (C)', 'Hornsby (A)']
# ...

# %%
# Top 20 LGA's in VIC.

no_of_females_VIC = []
LGA = []
x_VIC = []

for k in df['Code']:
    if str(k).startswith('2'):
        no_of_females_VIC.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
        
        
no_of_females_VIC.sort(reverse = True)
print(no_of_females_VIC[0:20])


for i in no_of_females_VIC[0:20]:
    x_VIC.append(i)
    print(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    LGA.append(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    #print(df.iloc[df['Total females'] == i, 'Name'].iloc[0])

print(LGA)
print(x_VIC)

#Bar Chart 
x_pos = [i for i, _ in enumerate(LGA)]
plt.bar(LGA, x_VIC)
plt.xlabel("Local Government Area")
plt.ylabel("Number of LGA's")
plt.title("Top 20 LGA's in VIC")
#plt.figure(figsize=(3,4))
plt.xticks(x_pos, LGA, rotation='vertical')
#plt.rcParams['figure.figsize'] = [10, 15]
plt.show()


print(x_VIC)
# Out:
# [169565, 128589, 126388, 112041, 112020, 103227, 100725, 93614, 92007, 89959, 86356, 85048, 83257, 82851, 82711, 80789, 79686, 78932, 78479, 72213]
# Casey (C)
# Greater Geelong (C)
# Wyndham (C)
# Hume (C)
# Whittlesea (C)
# Brimbank (C)
# Monash (C)
# Boroondara (C)
# Moreland (C)
# Whitehorse (C)
# Melbourne (C)
# Mornington Peninsula (S)
# Kingston (C) (Vic.)
# Knox (C)
# Darebin (C)
# Greater Dandenong (C)
# Yarra Ranges (S)
# Glen Eira (C)
# Melton (C)
# Frankston (C)
# ['Casey (C)', 'Greater Geelong (C)', 'Wyndham (C)', 'Hume (C)', 'Whittlesea (C)', 'Brimbank (C)', 'Monash (C)', 'Boroondara (C)', 'Moreland (C)', 'Whitehorse (C)', 'Melbourne (C)', 'Mornington Peninsula (S)', 'Kingston (C) (Vic.)', 'Knox (C)', 'Darebin (C)', 'Greater Dandenong (C)', 'Yarra Ranges (S)', 'Glen Eira (C)', 'Melton (C)', 'Frankston (C)']
# [169565, 128589, 126388, 112041, 112020, 103227, 100725, 93614, 92007, 89959, 86356, 85048, 83257, 82851, 82711, 80789, 79686, 78932, 78479, 72213]
# ...

# %%
x_NSW.extend(x_VIC)
x_NSW
# Out:
# [186196,
#  182947,
#  174907,
#  137760,
#  124201,
#  116377,
#  115639,
#  113743,
#  111927,
#  108871,
#  105823,
#  105019,
#  104718,
#  100497,
#  86872,
#  84988,
#  82554,
#  80000,
#  77514,
#  76336,
#  169565,
#  128589,
#  126388,
#  112041,
#  112020,
#  103227,
#  100725,
#  93614,
#  92007,
#  89959,
#  86356,
#  85048,
#  83257,
#  82851,
#  82711,
#  80789,
#  79686,
#  78932,
#  78479,
#  72213]

# %%
len(x_NSW)
# Out:
# 40

# %%
# Top 20 LGA's in Queensland.

no_of_females = []
LGA = []
x_QL = []

for k in df['Code']:
    if str(k).startswith('3'):
        no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
        
        
no_of_females.sort(reverse = True)
print(no_of_females[0:20])


for i in no_of_females[0:20]:
    x_QL.append(i)
    print(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    LGA.append(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    #print(df.iloc[df['Total females'] == i, 'Name'].iloc[0])

print(LGA)
print(x_QL)

#Bar Chart 
x_pos = [i for i, _ in enumerate(LGA)]

plt.bar(LGA, x_QL)
plt.xlabel("Local Government Area")
plt.ylabel("Number of LGA's")
plt.title("Top 20 LGA's in Queensland")
plt.xticks(x_pos, LGA, rotation='vertical')
plt.figure(figsize=(3,4))
#plt.rcParams['figure.figsize'] = [10, 15]
plt.show()

print(x_QL)
# Out:
# [622912, 310986, 233420, 165248, 164462, 107604, 96869, 85959, 83784, 79795, 57587, 53532, 48298, 41012, 30784, 28462, 25728, 21444, 20340, 18313]
# Brisbane (C)
# Gold Coast (C)
# Moreton Bay (R)
# Sunshine Coast (R)
# Logan (C)
# Ipswich (C)
# Townsville (C)
# Toowoomba (R)
# Cairns (R)
# Redland (C)
# Mackay (R)
# Fraser Coast (R)
# Bundaberg (R)
# Rockhampton (R)
# Gladstone (R)
# Noosa (S)
# Gympie (R)
# Scenic Rim (R)
# Lockyer Valley (R)
# Livingstone (S)
# ['Brisbane (C)', 'Gold Coast (C)', 'Moreton Bay (R)', 'Sunshine Coast (R)', 'Logan (C)', 'Ipswich (C)', 'Townsville (C)', 'Toowoomba (R)', 'Cairns (R)', 'Redland (C)', 'Mackay (R)', 'Fraser Coast (R)', 'Bundaberg (R)', 'Rockhampton (R)', 'Gladstone (R)', 'Noosa (S)', 'Gympie (R)', 'Scenic Rim (R)', 'Lockyer Valley (R)', 'Livingstone (S)']
# [622912, 310986, 233420, 165248, 164462, 107604, 96869, 85959, 83784, 79795, 57587, 53532, 48298, 41012, 30784, 28462, 25728, 21444, 20340, 18313]
# ...

# %%
x_NSW.extend(x_QL)

# %%
len(x_NSW)
# Out:
# 60

# %%
# Top 20 LGA's in South Australia.

no_of_females = []
LGA = []
x_SA = []

for k in df['Code']:
    if str(k).startswith('4'):
        no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
        
        
no_of_females.sort(reverse = True)
print(no_of_females[0:20])


for i in no_of_females[0:20]:
    x_SA.append(i)
    print(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    LGA.append(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    #print(df.iloc[df['Total females'] == i, 'Name'].iloc[0])

print(LGA)
print(x_SA)

#Bar Chart 
x_pos = [i for i, _ in enumerate(LGA)]

plt.bar(LGA, x_SA)
plt.xlabel("Local Government Area")
plt.ylabel("Number of LGA's")
plt.title("Top 20 LGA's in South Australia")
plt.xticks(x_pos, LGA, rotation='vertical')
plt.figure(figsize=(3,4))
#plt.rcParams['figure.figsize'] = [10, 15]
plt.show()

print(x_SA)
# Out:
# [87281, 71066, 63350, 59707, 50721, 47798, 47013, 34602, 30524, 26177, 23961, 20576, 19941, 19312, 19004, 18154, 14076, 13955, 12583, 12386]
# Onkaparinga (C)
# Salisbury (C)
# Port Adelaide Enfield (C)
# Charles Sturt (C)
# Tea Tree Gully (C)
# Marion (C)
# Playford (C)
# Mitcham (C)
# West Torrens (C)
# Campbelltown (C) (SA)
# Burnside (C)
# Unley (C)
# Adelaide Hills (DC)
# Holdfast Bay (C)
# Norwood Payneham St Peters (C)
# Mount Barker (DC)
# Mount Gambier (C)
# Alexandrina (DC)
# Barossa (DC)
# Gawler (T)
# ['Onkaparinga (C)', 'Salisbury (C)', 'Port Adelaide Enfield (C)', 'Charles Sturt (C)', 'Tea Tree Gully (C)', 'Marion (C)', 'Playford (C)', 'Mitcham (C)', 'West Torrens (C)', 'Campbelltown (C) (SA)', 'Burnside (C)', 'Unley (C)', 'Adelaide Hills (DC)', 'Holdfast Bay (C)', 'Norwood Payneham St Peters (C)', 'Mount Barker (DC)', 'Mount Gambier (C)', 'Alexandrina (DC)', 'Barossa (DC)', 'Gawler (T)']
# ...

# %%
x_NSW.extend(x_SA)

# %%
len(x_NSW)
# Out:
# 80

# %%
# Top 20 LGA's in Western Australia.

no_of_females = []
LGA = []
x_WA = []

for k in df['Code']:
    if str(k).startswith('5'):
        no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
        
        
no_of_females.sort(reverse = True)
print(no_of_females[0:20])


for i in no_of_females[0:20]:
    x_WA.append(i)
    print(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    LGA.append(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    #print(df.iloc[df['Total females'] == i, 'Name'].iloc[0])

print(LGA)
print(x_WA)

#Bar Chart 
x_pos = [i for i, _ in enumerate(LGA)]

plt.bar(LGA, x_WA)
plt.xlabel("Local Government Area")
plt.ylabel("Number of LGA's")
plt.title("Top 20 LGA's in Western Australia")
plt.xticks(x_pos, LGA, rotation='vertical')
plt.figure(figsize=(3,4))
#plt.rcParams['figure.figsize'] = [10, 15]
plt.show()

print(x_WA)
# Out:
# [112471, 102741, 80459, 72531.92106627871, 67072, 60644, 56640, 52480, 46130, 43835, 43675, 33317.0789337213, 29574, 22213, 20956, 20246, 20149, 19778, 19230, 18718]
# Stirling (C)
# Wanneroo (C)
# Joondalup (C)
# Swan (C)
# Rockingham (C)
# Gosnells (C)
# Cockburn (C)
# Melville (C)
# Canning (C)
# Armadale (C)
# Mandurah (C)
# Bayswater (C)
# Kalamunda (S)
# South Perth (C)
# Kwinana (C)
# Belmont (C)
# Busselton (C)
# Greater Geraldton (C)
# Albany (C)
# Mundaring (S)
# ['Stirling (C)', 'Wanneroo (C)', 'Joondalup (C)', 'Swan (C)', 'Rockingham (C)', 'Gosnells (C)', 'Cockburn (C)', 'Melville (C)', 'Canning (C)', 'Armadale (C)', 'Mandurah (C)', 'Bayswater (C)', 'Kalamunda (S)', 'South Perth (C)', 'Kwinana (C)', 'Belmont (C)', 'Busselton (C)', 'Greater Geraldton (C)', 'Albany (C)', 'Mundaring (S)']
# [112471, 102741, 80459, 72531.92106627871, 67072, 60644, 56640, 52480, 46130, 43835, 43675, 33317.0789337213, 29574, 22213, 20956, 20246, 20149, 19778, 19230, 18718]
# ...

# %%
x_NSW.extend(x_WA)

# %%
len(x_NSW)
# Out:
# 100

# %%
# Top 20 LGA's in Tasmania.

no_of_females = []
LGA = []
x_T = []

for k in df['Code']:
    if str(k).startswith('6'):
        no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
        
        
no_of_females.sort(reverse = True)
print(no_of_females[0:20])


for i in no_of_females[0:20]:
    x_T.append(i)
    print(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    LGA.append(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    #print(df.iloc[df['Total females'] == i, 'Name'].iloc[0])

print(LGA)
print(x_T)

#Bar Chart 
x_pos = [i for i, _ in enumerate(LGA)]

plt.bar(LGA, x_T)
plt.xlabel("Local Government Area")
plt.ylabel("Number of LGA's")
plt.title("Top 20 LGA's in Tasmania")
plt.xticks(x_pos, LGA, rotation='vertical')
plt.figure(figsize=(3,4))
#plt.rcParams['figure.figsize'] = [10, 15]
plt.show()

print(x_T)
# Out:
# [34652, 28618, 26898, 23844, 19158, 13338, 12120, 11267, 10129, 9977, 8641, 8609, 7543, 6970, 6673, 5763, 5065, 3960, 3478, 3315]
# Launceston (C)
# Clarence (C)
# Hobart (C)
# Glenorchy (C)
# Kingborough (M)
# Devonport (C)
# West Tamar (M)
# Central Coast (M)
# Meander Valley (M)
# Burnie (C)
# Huon Valley (M)
# Brighton (M)
# Sorell (M)
# Waratah/Wynyard (M)
# Northern Midlands (M)
# Latrobe (M)
# Derwent Valley (M)
# Circular Head (M)
# George Town (M)
# Dorset (M)
# ['Launceston (C)', 'Clarence (C)', 'Hobart (C)', 'Glenorchy (C)', 'Kingborough (M)', 'Devonport (C)', 'West Tamar (M)', 'Central Coast (M)', 'Meander Valley (M)', 'Burnie (C)', 'Huon Valley (M)', 'Brighton (M)', 'Sorell (M)', 'Waratah/Wynyard (M)', 'Northern Midlands (M)', 'Latrobe (M)', 'Derwent Valley (M)', 'Circular Head (M)', 'George Town (M)', 'Dorset (M)']
# [34652, 28618, 26898, 23844, 19158, 13338, 12120, 11267, 10129, 9977, 8641, 8609, 7543, 6970, 6673, 5763, 5065, 3960, 3478, 3315]
# ...

# %%
x_NSW.extend(x_T)

# %%
len(x_NSW)
# Out:
# 120

# %%
# Top 20 LGA's in Northern Territory.

no_of_females = []
LGA = []
x_NT = []

for k in df['Code']:
    if str(k).startswith('7'):
        no_of_females.append(df.loc[df['Code'] == k, 'Total females'].iloc[0])
        
        
no_of_females.sort(reverse = True)
print(no_of_females[0:20])


for i in no_of_females[0:20]:
    x_NT.append(i)
    print(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    LGA.append(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    #print(df.iloc[df['Total females'] == i, 'Name'].iloc[0])

print(LGA)
print(x_NT)

#Bar Chart 
x_pos = [i for i, _ in enumerate(LGA)]

plt.bar(LGA, x_NT)
plt.xlabel("Local Government Area")
plt.ylabel("Number of LGA's")
plt.title("Top 20 LGA's in Northern Territory")
plt.xticks(x_pos, LGA, rotation='vertical')
plt.figure(figsize=(3,4))
#plt.rcParams['figure.figsize'] = [10, 15]
plt.show()

print(x_NT)
# Out:
# [41254, 18664, 13591, 10216, 5170, 5035, 3634, 3610, 3372, 3343, 3340, 2145, 1878, 1493, 1356, 679, 238, 73]
# Darwin (C)
# Palmerston (C)
# Alice Springs (T)
# Litchfield (M)
# East Arnhem (R)
# Katherine (T)
# Barkly (R)
# Roper Gulf (R)
# West Arnhem (R)
# Unincorporated NT
# MacDonnell (R)
# Central Desert (R)
# West Daly (R)
# Victoria Daly (R)
# Tiwi Islands (R)
# Coomalie (S)
# Wagait (S)
# Murchison (S)
# ['Darwin (C)', 'Palmerston (C)', 'Alice Springs (T)', 'Litchfield (M)', 'East Arnhem (R)', 'Katherine (T)', 'Barkly (R)', 'Roper Gulf (R)', 'West Arnhem (R)', 'Unincorporated NT', 'MacDonnell (R)', 'Central Desert (R)', 'West Daly (R)', 'Victoria Daly (R)', 'Tiwi Islands (R)', 'Coomalie (S)', 'Wagait (S)', 'Murchison (S)']
# [41254, 18664, 13591, 10216, 5170, 5035, 3634, 3610, 3372, 3343, 3340, 2145, 1878, 1493, 1356, 679, 238, 73]
# [41254, 18664, 13591, 10216, 5170, 5035, 3634, 3610, 3372, 3343, 3340, 2145, 1878, 1493, 1356, 679, 238, 73]

# %%
x_NSW.extend(x_NT)

# %%
len(x_NSW)
# Out:
# 138

# %%
Top_20_LGA = []   
LGA = []

x_NSW.sort(reverse = True)
print(x_NSW[0:20])


for i in x_NSW[0:20]:
    Top_20_LGA.append(i)
    print(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    LGA.append(df.loc[df['Total females'] == i, 'Name'].iloc[0])
    #print(df.iloc[df['Total females'] == i, 'Name'].iloc[0])

print(LGA)
print(x_NT)

# #Bar Chart 
x_pos = [i for i, _ in enumerate(LGA)]

plt.bar(LGA, Top_20_LGA)
plt.xlabel("Local Government Area")
plt.ylabel("Number of LGA's")
plt.title("Top 20 LGA's in Northern Territory")
plt.xticks(x_pos, LGA, rotation='vertical')
plt.figure(figsize=(3,4))
#plt.rcParams['figure.figsize'] = [10, 15]
plt.show()
# Out:
# [622912, 310986, 233420, 186196, 182947, 174907, 169565, 165248, 164462, 137760, 128589, 126388, 124201, 116377, 115639, 113743, 112471, 112041, 112020, 111927]
# Brisbane (C)
# Gold Coast (C)
# Moreton Bay (R)
# Canterbury-Bankstown (A)
# Blacktown (C)
# Central Coast (C) (NSW)
# Casey (C)
# Sunshine Coast (R)
# Logan (C)
# Northern Beaches (A)
# Greater Geelong (C)
# Wyndham (C)
# Parramatta (C)
# Sutherland Shire (A)
# Sydney (C)
# Cumberland (A)
# Stirling (C)
# Hume (C)
# Whittlesea (C)
# Liverpool (C)
# ['Brisbane (C)', 'Gold Coast (C)', 'Moreton Bay (R)', 'Canterbury-Bankstown (A)', 'Blacktown (C)', 'Central Coast (C) (NSW)', 'Casey (C)', 'Sunshine Coast (R)', 'Logan (C)', 'Northern Beaches (A)', 'Greater Geelong (C)', 'Wyndham (C)', 'Parramatta (C)', 'Sutherland Shire (A)', 'Sydney (C)', 'Cumberland (A)', 'Stirling (C)', 'Hume (C)', 'Whittlesea (C)', 'Liverpool (C)']
# ...
